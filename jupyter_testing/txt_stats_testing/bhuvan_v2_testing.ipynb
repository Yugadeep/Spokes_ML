# %%
import pandas as pd
import re
import os
import glob
import numpy as np

# %%
px_txt = glob.glob("../../../data/2023_imagery/filtered/074_SPKLFMOV/*CALIB_ML.txt")
test_txt = px_txt[0]
len(px_txt)
# Out:
# 17

# %%
test_df = pd.read_csv(test_txt, delimiter = "	")
test_df.head()
# Out:
#           # Rad       Long  Intensity  Spoke Number
# 0  97924.528302  67.970383   0.305719             1
# 1  97924.528302  68.170922   0.308240             1
# 2  97924.528302  68.371462   0.310918             1
# 3  97924.528302  68.572002   0.312546             1
# 4  97924.528302  68.772541   0.308479             1

# %%
filename = os.path.basename(test_txt)
# Out:
# 'W1593680167_1_CALIB_ML.txt'

# %%
min_rad = test_df['# Rad'].min()
max_rad = test_df['# Rad'].max()
min_lon = test_df['Long'].min()
max_lon = test_df['Long'].max()

# %%
num_spokes = test_df['Spoke Number'].unique()[-1]
num_spokes
# Out:
# 2

# %%
# test for spoke numbers
# Ask about the test, then write a test for the others
if spoke_numbers[0] == 1:
    compare_list = [i for i in range(1, len(spoke_numbers)+1)]

    if set(spoke_numbers) == set(compare_list):
        print("Spoke Number passed the test")
# Out:
# Spoke Number passed the test

# %%
num_pix = len(test_df)

# %%
avg_pix_per_spoke = test_df.groupby('Spoke Number')['Intensity'].count().mean()

# %%
empty_file = "../../../data/2023_imagery/filtered/074_SPKLFMOV/W1593702596_1_CALIB_ML.txt"
empty_df = pd.read_csv(empty_file, delimiter = "	")
if len(empty_df) == 0:
    print('this file is empty')
    df_dict = {"filename": filename, "min_rad": [np.nan], "max_rad": [np.nan], "min_lon": [np.nan], "max_lon": [np.nan], "num_spokes": 0, "avg_pix_per_spoke":0}

    empty_df = pd.DataFrame(df_dict)

empty_df = empty_df.set_index('filename')
empty_df
# Out:
# this file is empty
#                             min_rad  max_rad  min_lon  max_lon  num_spokes
# filename
# W1593680167_1_CALIB_ML.txt      NaN      NaN      NaN      NaN           0

# %%
def bypixel_summary(txt_path):
    in_df = pd.read_csv(txt_path, delimiter = "	")
    filename = os.path.basename(txt_path)

    #
    if len(in_df) == 0:
        print('this file is empty')
        df_dict = {"filename": filename, "min_rad": [np.nan], "max_rad": [np.nan], "min_lon": [np.nan], "max_lon": [np.nan], "num_spokes": 0, "num_pix":0, "avg_pix_per_spoke":0}

        empty_df = pd.DataFrame(df_dict)
        empty_df = empty_df.set_index('filename')
        return empty_df

    

    min_rad = round(in_df['# Rad'].min(), 3)
    max_rad = round(in_df['# Rad'].max(), 3)
    min_lon = round(in_df['Long'].min(), 3)
    max_lon = round(in_df['Long'].max(), 3)

    num_spokes = in_df['Spoke Number'].unique()[-1]
    num_pix = len(in_df)
    avg_pix_per_spoke = round(in_df.groupby('Spoke Number')['Intensity'].count().mean(), 3)

    df_dict = {"filename": filename, "min_rad": min_rad, "max_rad": max_rad, "min_lon": min_lon, "max_lon": max_lon, "num_spokes": num_spokes, "num_pix":num_pix, "avg_pix_per_spoke":avg_pix_per_spoke}    
    full_df = pd.DataFrame(df_dict, index = [0])
    full_df = full_df.set_index("filename")

    return full_df

# %%
frame_list = []

for path in px_txt:
    frame_list.append(bypixel_summary(path))
total_list = pd.concat(frame_list, axis = 0)
total_list
# Out:
# this file is empty
# this file is empty
#                               min_rad     max_rad  min_lon  max_lon  \
# filename
# W1593680167_1_CALIB_ML.txt  92264.151  106792.453   40.095   75.390
# W1593690362_1_CALIB_ML.txt  91509.434  107924.528   27.623  167.364
# W1593704635_1_CALIB_ML.txt  97358.491  104716.981   22.651   33.367
# W1593702596_1_CALIB_ML.txt        NaN         NaN      NaN      NaN
# W1593698518_1_CALIB_ML.txt  90000.000  105283.019  156.764  174.414
# W1593708713_1_CALIB_ML.txt  90000.000  105094.340  148.052  179.112
# W1593684245_1_CALIB_ML.txt  90000.000  100566.038   38.495  180.273
# W1593694440_1_CALIB_ML.txt  96226.415  110566.038   78.646  174.192
# W1593688323_1_CALIB_ML.txt  90943.396  109245.283   41.725  177.053
# W1593678128_1_CALIB_ML.txt  93396.226  102075.472  125.963  136.283
# W1593686284_1_CALIB_ML.txt  90943.396  107358.491   81.394  171.664
# W1593696479_1_CALIB_ML.txt  98113.208  110754.717   86.595  176.916
# W1593692401_1_CALIB_ML.txt  94905.660  106603.774   48.755  182.958
# W1593676089_1_CALIB_ML.txt  90000.000  100377.358   62.547  169.200
# W1593700557_1_CALIB_ML.txt        NaN         NaN      NaN      NaN
# W1593706674_1_CALIB_ML.txt  90000.000  105471.698   75.300  175.205
# W1593682206_1_CALIB_ML.txt  92075.472  106981.132  106.243  132.575
#
#                             num_spokes  num_pix  avg_pix_per_spoke
# filename
# W1593680167_1_CALIB_ML.txt           2     4297           2148.500
# W1593690362_1_CALIB_ML.txt           7     8839           1262.714
# W1593704635_1_CALIB_ML.txt           1     1115           1115.000
# W1593702596_1_CALIB_ML.txt           0        0              0.000
# W1593698518_1_CALIB_ML.txt           2     1743            871.500
# W1593708713_1_CALIB_ML.txt           1     3679           3679.000
# W1593684245_1_CALIB_ML.txt           4     3649            912.250
# W1593694440_1_CALIB_ML.txt           2     4634           2317.000
# W1593688323_1_CALIB_ML.txt           6     9511           1585.167
# W1593678128_1_CALIB_ML.txt           1     1818           1818.000
# W1593686284_1_CALIB_ML.txt           5     4708            941.600
# W1593696479_1_CALIB_ML.txt           3     4327           1442.333
# W1593692401_1_CALIB_ML.txt           4     4388           1097.000
# W1593676089_1_CALIB_ML.txt           3     2506            835.333
# W1593700557_1_CALIB_ML.txt           0        0              0.000
# W1593706674_1_CALIB_ML.txt           2     4068           2034.000
# W1593682206_1_CALIB_ML.txt           1     4500           4500.000

# %% [markdown]
# # Compare Bhuvan's table to my table

# %%
bhuvans = pd.read_csv("../../../../../../../Downloads/output_Will.txt", delimiter = r'\s+')
bhuvans = pd.read_fwf("../../../../../../../Downloads/output_Will.txt")

# %%
bhuvans = bhuvans.rename(columns= {"# File_Name": "filename"})
bhuvans = bhuvans.set_index('filename')

# %%
my_names = {"max_rad": [np.nan], "min_rad": [np.nan], "max_lon": [np.nan], "min_lon": [np.nan],  "num_spokes": 0, "num_pix":0, "avg_pix_per_spoke":0}
my_names = my_names.keys()
my_names
# Out:
# dict_keys(['max_rad', 'min_rad', 'max_lon', 'min_lon', 'num_spokes', 'num_pix', 'avg_pix_per_spoke'])

# %%
rename_dict = dict(zip(bhuvans.columns, my_names))
rename_dict

bhuvans = bhuvans.rename(columns = rename_dict)

# %%
bhuvans = bhuvans[['min_rad', 'max_rad', 'min_lon', 'max_lon', 'num_spokes', 'num_pix', 'avg_pix_per_spoke']]
bhuvans
# Out:
#                                 min_rad     max_rad   min_lon   max_lon  \
# filename
# W1593680167_1_CALIB_ML.txt    92264.151  106792.453    40.095    75.390
# W1593690362_1_CALIB_ML.txt    91509.434  107924.528    27.623   167.364
# W1593704635_1_CALIB_ML.txt    97358.491  104716.981    22.651    33.367
# W1593702596_1_CALIB_ML.txt  1000000.000   -9999.000  9999.000 -9999.000
# W1593698518_1_CALIB_ML.txt    90000.000  105283.019   156.764   174.414
# W1593708713_1_CALIB_ML.txt    90000.000  105094.340   148.052   179.112
# W1593684245_1_CALIB_ML.txt    90000.000  100566.038    38.495   180.273
# W1593694440_1_CALIB_ML.txt    96226.415  110566.038    78.646   174.192
# W1593688323_1_CALIB_ML.txt    90943.396  109245.283    41.725   177.053
# W1593678128_1_CALIB_ML.txt    93396.226  102075.472   125.963   136.283
# W1593686284_1_CALIB_ML.txt    90943.396  107358.491    81.394   171.664
# W1593696479_1_CALIB_ML.txt    98113.208  110754.717    86.595   176.916
# W1593692401_1_CALIB_ML.txt    94905.660  106603.774    48.755   182.958
# W1593676089_1_CALIB_ML.txt    90000.000  100377.358    62.547   169.200
# W1593700557_1_CALIB_ML.txt  1000000.000   -9999.000  9999.000 -9999.000
# W1593706674_1_CALIB_ML.txt    90000.000  105471.698    75.300   175.205
# W1593682206_1_CALIB_ML.txt    92075.472  106981.132   106.243   132.575
#
#                             num_spokes  num_pix  avg_pix_per_spoke
# filename
# W1593680167_1_CALIB_ML.txt           2     4297           2148.500
# W1593690362_1_CALIB_ML.txt           7     8839           1262.714
# W1593704635_1_CALIB_ML.txt           1     1115           1115.000
# W1593702596_1_CALIB_ML.txt           1        0              0.000
# W1593698518_1_CALIB_ML.txt           2     1743            871.500
# W1593708713_1_CALIB_ML.txt           1     3679           3679.000
# W1593684245_1_CALIB_ML.txt           4     3649            912.250
# W1593694440_1_CALIB_ML.txt           2     4634           2317.000
# W1593688323_1_CALIB_ML.txt           6     9511           1585.167
# W1593678128_1_CALIB_ML.txt           1     1818           1818.000
# W1593686284_1_CALIB_ML.txt           5     4708            941.600
# W1593696479_1_CALIB_ML.txt           3     4327           1442.333
# W1593692401_1_CALIB_ML.txt           4     4388           1097.000
# W1593676089_1_CALIB_ML.txt           3     2506            835.333
# W1593700557_1_CALIB_ML.txt           1        0              0.000
# W1593706674_1_CALIB_ML.txt           2     4068           2034.000
# W1593682206_1_CALIB_ML.txt           1     4500           4500.000

# %%
total_list
# Out:
#                               min_rad     max_rad  min_lon  max_lon  \
# filename
# W1593680167_1_CALIB_ML.txt  92264.151  106792.453   40.095   75.390
# W1593690362_1_CALIB_ML.txt  91509.434  107924.528   27.623  167.364
# W1593704635_1_CALIB_ML.txt  97358.491  104716.981   22.651   33.367
# W1593702596_1_CALIB_ML.txt        NaN         NaN      NaN      NaN
# W1593698518_1_CALIB_ML.txt  90000.000  105283.019  156.764  174.414
# W1593708713_1_CALIB_ML.txt  90000.000  105094.340  148.052  179.112
# W1593684245_1_CALIB_ML.txt  90000.000  100566.038   38.495  180.273
# W1593694440_1_CALIB_ML.txt  96226.415  110566.038   78.646  174.192
# W1593688323_1_CALIB_ML.txt  90943.396  109245.283   41.725  177.053
# W1593678128_1_CALIB_ML.txt  93396.226  102075.472  125.963  136.283
# W1593686284_1_CALIB_ML.txt  90943.396  107358.491   81.394  171.664
# W1593696479_1_CALIB_ML.txt  98113.208  110754.717   86.595  176.916
# W1593692401_1_CALIB_ML.txt  94905.660  106603.774   48.755  182.958
# W1593676089_1_CALIB_ML.txt  90000.000  100377.358   62.547  169.200
# W1593700557_1_CALIB_ML.txt        NaN         NaN      NaN      NaN
# W1593706674_1_CALIB_ML.txt  90000.000  105471.698   75.300  175.205
# W1593682206_1_CALIB_ML.txt  92075.472  106981.132  106.243  132.575
#
#                             num_spokes  num_pix  avg_pix_per_spoke
# filename
# W1593680167_1_CALIB_ML.txt           2     4297           2148.500
# W1593690362_1_CALIB_ML.txt           7     8839           1262.714
# W1593704635_1_CALIB_ML.txt           1     1115           1115.000
# W1593702596_1_CALIB_ML.txt           0        0              0.000
# W1593698518_1_CALIB_ML.txt           2     1743            871.500
# W1593708713_1_CALIB_ML.txt           1     3679           3679.000
# W1593684245_1_CALIB_ML.txt           4     3649            912.250
# W1593694440_1_CALIB_ML.txt           2     4634           2317.000
# W1593688323_1_CALIB_ML.txt           6     9511           1585.167
# W1593678128_1_CALIB_ML.txt           1     1818           1818.000
# W1593686284_1_CALIB_ML.txt           5     4708            941.600
# W1593696479_1_CALIB_ML.txt           3     4327           1442.333
# W1593692401_1_CALIB_ML.txt           4     4388           1097.000
# W1593676089_1_CALIB_ML.txt           3     2506            835.333
# W1593700557_1_CALIB_ML.txt           0        0              0.000
# W1593706674_1_CALIB_ML.txt           2     4068           2034.000
# W1593682206_1_CALIB_ML.txt           1     4500           4500.000

# %%
total_list.compare(bhuvans)
# Out:
#                            min_rad            max_rad         min_lon          \
#                               self      other    self   other    self   other
# filename
# W1593702596_1_CALIB_ML.txt     NaN  1000000.0     NaN -9999.0     NaN  9999.0
# W1593700557_1_CALIB_ML.txt     NaN  1000000.0     NaN -9999.0     NaN  9999.0
#
#                            max_lon         num_spokes
#                               self   other       self other
# filename
# W1593702596_1_CALIB_ML.txt     NaN -9999.0        0.0   1.0
# W1593700557_1_CALIB_ML.txt     NaN -9999.0        0.0   1.0
