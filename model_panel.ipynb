# %%
import json
import model_utility
import glob
import matplotlib.pyplot as plt
import albumentations as alb
import cv2

# %%
f, axes = plt.subplots(2, 2, sharey=True, figsize=(12,8))
glob.glob("../models/dark/*.json")
axes = axes.flatten()
f.suptitle("Spoke Training and validation accuracy")

for path, axs in zip(glob.glob("../models/dark/*.json"), axes):

    plot_num = int(f"31{glob.glob('../models/dark/*.json').index(path)}")+1
    model_utility.display_results(path, axs)
plt.show()
# Out:
# Which model is this? - darkRBCAug_spoke_360im_300e_resnet34.json
# Last Train IOU Score:  0.9874510169029236
# Last Train Loss Score:  0.0008252133848145604
# Last Validation IOU Score:  0.9841936826705933
# Last Validation Loss Score:  0.0010403424967080355
# Which model is this? - dark2Aug_spoke_360im_300e_resnet34.json
# Last Train IOU Score:  0.9745001792907715
# Last Train Loss Score:  0.0018583517521619797
# Last Validation IOU Score:  0.9063780903816223
# Last Validation Loss Score:  0.019610561430454254
# Which model is this? - dark_spoke_60im_300e_resnet34.json
# Last Train IOU Score:  0.68120276927948
# Last Train Loss Score:  0.051005199551582336
# Last Validation IOU Score:  0.22087793052196503
# Last Validation Loss Score:  0.28213876485824585
# Which model is this? - darkSSRAug_spoke_360im_300e_resnet34.json
# Last Train IOU Score:  0.979138195514679
# Last Train Loss Score:  0.0014739575562998652
# Last Validation IOU Score:  0.9509808421134949
# ...
